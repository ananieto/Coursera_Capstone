# %% [markdown]
# # Project: The Battle of Neighborhoods
#
# ## Introduction
# Salamanca is a Spanish university city. Due to the large number of students, most of the services available in the city are oriented to meet the needs of university students.
# Above all, there are many food establishments.
# However, food from establishments close to university areas does not offer good quality food and managers are not aware of creating businesses that respect sustainability and provide ecological products.
# That's why Pepe, a citizen of Salamanca wants to embark on a sustainable business that sells organic products and food made from them.
#
#
# ## Objetive
#
# The aim of this work is to provide Pepe with a tool that, using machine learning techniques, provides Pepe with information about the services available in the city so that he can choose the area that best suits him to start his business.
#
#
# ## Data
#
# In order to solve the problem we use the data provided by the web foursquare for the coordinates of the city of Salamanca.
#
# In the first place the coordinates of the city centre will be obtained.
#
# Then, a query in the Foursquare website is done to obtain the top sites in Salamanca with their geographical coordinates.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2019.9.11  |       hecc5488_0         144 KB  conda-forge
#     openssl-1.1.1d             |       h516909a_0         2.1 MB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     certifi-2019.9.11          |           py36_0         147 KB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0         conda-forge
#     geopy:           1.20.0-py_0       conda-forge
#
# The following packages will be UPDATED:
#
#     certifi:         2019.9.11-py36_0              --> 2019.9.11-py36_0     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     ca-certificates: 2019.10.16-0                  --> 2019.9.11-hecc5488_0 conda-forge
#     openssl:         1.1.1d-h7b6447c_3             --> 1.1.1d-h516909a_0    conda-forge
#
#
# Downloading and Extracting Packages
# ca-certificates-2019 | 144 KB    | ##################################### | 100%
# openssl-1.1.1d       | 2.1 MB    | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# certifi-2019.9.11    | 147 KB    | ##################################### | 100%
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     altair-3.2.0               |           py36_0         770 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         868 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  3.2.0-py36_0 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
#
# Downloading and Extracting Packages
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# altair-3.2.0         | 770 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %%
url='http://www.gpspostcode.com/zip-code/spain/salamanca/?tri=cp_asc'

df=pd.read_html(url, header=0)[0]

df.head(15)
# Out:
#     Unnamed: 0  Zip code                      City        X       Y
# 0          NaN     37001                 Salamanca  40.9682 -5.6643
# 1          NaN     37100                   Ledesma  41.0867 -6.0012
# 2          NaN     37110  San pelayo de la guareña  41.1353 -5.8302
# 3          NaN     37110                    Santiz  41.2055 -5.8975
# 4          NaN     37110             Aldearrodrigo  41.1100 -5.8077
# 5          NaN     37110             Torresmenudas  41.1021 -5.7834
# 6          NaN     37110                   Zamayon  41.1494 -5.8306
# 7          NaN     37110                   El arco  41.1104 -5.8245
# 8          NaN     37111                  Palacino  41.1527 -5.9033
# 9          NaN     37111    Palacios del arzobispo  41.1653 -5.8905
# 10         NaN     37111             Espino rapado  41.1515 -5.9016
# 11         NaN     37111          Añover de tormes  41.1359 -5.9156
# 12         NaN     37114                   Espayos  41.0500 -6.1040
# 13         NaN     37114  Villaseco de los gamitos  41.0352 -6.1138
# 14         NaN     37114                  Valrubio  41.0500 -6.1051

# %%
df=df.drop(['Unnamed: 0'], axis=1)
df.head(10)
# Out:
#    Zip code                      City        X       Y
# 0     37001                 Salamanca  40.9682 -5.6643
# 1     37100                   Ledesma  41.0867 -6.0012
# 2     37110  San pelayo de la guareña  41.1353 -5.8302
# 3     37110                    Santiz  41.2055 -5.8975
# 4     37110             Aldearrodrigo  41.1100 -5.8077
# 5     37110             Torresmenudas  41.1021 -5.7834
# 6     37110                   Zamayon  41.1494 -5.8306
# 7     37110                   El arco  41.1104 -5.8245
# 8     37111                  Palacino  41.1527 -5.9033
# 9     37111    Palacios del arzobispo  41.1653 -5.8905

# %%
df=df.rename(columns={'Zip code':'zipcode'})
df.head(10)
# Out:
#    zipcode                      City        X       Y
# 0    37001                 Salamanca  40.9682 -5.6643
# 1    37100                   Ledesma  41.0867 -6.0012
# 2    37110  San pelayo de la guareña  41.1353 -5.8302
# 3    37110                    Santiz  41.2055 -5.8975
# 4    37110             Aldearrodrigo  41.1100 -5.8077
# 5    37110             Torresmenudas  41.1021 -5.7834
# 6    37110                   Zamayon  41.1494 -5.8306
# 7    37110                   El arco  41.1104 -5.8245
# 8    37111                  Palacino  41.1527 -5.9033
# 9    37111    Palacios del arzobispo  41.1653 -5.8905

# %%
address = 'Salamanca'
geolocator = Nominatim(user_agent="Salamanca")
location = geolocator.geocode(address)
latitude_sal = location.latitude
longitude_sal = location.longitude
print('The geograpical coordinates of Salamanca are {}, {}.'.format(latitude_sal, longitude_sal))
# Out:
# The geograpical coordinates of Salamanca are 40.9651572, -5.6640182.

# %%
map_sal = folium.Map(location=[latitude_sal, longitude_sal], zoom_start=20)

# add markers to map
for zipcode, City, X, Y in zip(df['zipcode'], df['City'], df['X'], df['Y']):
    label = '{}, {}'.format(zipcode,City)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [latitude_sal, longitude_sal],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_sal)  
    
map_sal
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = 'QIWCWGVQZAZS5KEKEJ3HP5ZACX1PJ3CISJKNHREH5CIVO2KI' # your Foursquare ID
CLIENT_SECRET = 'H4ISQZTNOL1LLFA3IOZ0VVB1TZYYEDZWPUYOU1SSF2AOCDW3' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: QIWCWGVQZAZS5KEKEJ3HP5ZACX1PJ3CISJKNHREH5CIVO2KI
# CLIENT_SECRET:H4ISQZTNOL1LLFA3IOZ0VVB1TZYYEDZWPUYOU1SSF2AOCDW3

# %%
LIMIT = 200 # limit of number of venues returned by Foursquare API

radius = 1500 # define radius

# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude_sal, 
    longitude_sal, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=QIWCWGVQZAZS5KEKEJ3HP5ZACX1PJ3CISJKNHREH5CIVO2KI&client_secret=H4ISQZTNOL1LLFA3IOZ0VVB1TZYYEDZWPUYOU1SSF2AOCDW3&v=20180605&ll=40.9651572,-5.6640182&radius=1500&limit=200'

# %%
results = requests.get(url).json()

# %%
results
# Out:
# {'meta': {'code': 200, 'requestId': '5dcd188b0be7b4001bfadbcb'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Salamanca',
#   'headerFullLocation': 'Salamanca',
#   'headerLocationGranularity': 'city',
#   'totalResults': 165,
#   'suggestedBounds': {'ne': {'lat': 40.978657213500014,
#     'lng': -5.646173335139151},
#    'sw': {'lat': 40.951657186499986, 'lng': -5.681863064860849}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7f4c0ef964a520c32530e3',
#        'name': 'Plaza Mayor',
#        'location': {'address': 'Pl. Mayor',
#         'lat': 40.965009280015074,
#         'lng': -5.664117336273193,
#         'distance': 18,
#         'postalCode': '37002',
#         'cc': 'ES',
#         'neighborhood': 'Centro',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Pl. Mayor',
#          '37002 Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7f4c0ef964a520c32530e3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4de94e6e1f6e9b537723d09b',
#        'name': 'Cuzco Bodega',
#        'location': {'address': 'C. Juan del Rey, 1-3',
#         'lat': 40.96417,
#         'lng': -5.6655674,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96417,
#           'lng': -5.6655674}],
#         'distance': 170,
#         'postalCode': '37002',
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['C. Juan del Rey, 1-3',
#          '37002 Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1db931735',
#          'name': 'Tapas Restaurant',
#          'pluralName': 'Tapas Restaurants',
#          'shortName': 'Tapas',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4de94e6e1f6e9b537723d09b-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd35a2fcaff95214eb5d4f0',
#        'name': 'Capitán Haddock',
#        'location': {'address': 'C. Concejo, 13',
#         'lat': 40.96640575966223,
#         'lng': -5.664584265200162,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96640575966223,
#           'lng': -5.664584265200162}],
#         'distance': 146,
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['C. Concejo, 13',
#          'Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'shortName': 'Cocktail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd35a2fcaff95214eb5d4f0-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5001f167e4b01f40ce27e71d',
#        'name': 'The Holy Cross',
#        'location': {'address': 'C. Obispo Jarrín, 12',
#         'lat': 40.96472788676771,
#         'lng': -5.661909723099955,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96472788676771,
#           'lng': -5.661909723099955}],
#         'distance': 183,
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['C. Obispo Jarrín, 12',
#          'Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'shortName': 'Pub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '35391571'}},
#       'referralId': 'e-0-5001f167e4b01f40ce27e71d-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c497ecbb5eec9b6e94acfa4',
#        'name': 'Doctrinos',
#        'location': {'address': 'C. Doctrinos, 3',
#         'lat': 40.964728361019084,
#         'lng': -5.6659485116346024,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.964728361019084,
#           'lng': -5.6659485116346024}],
#         'distance': 169,
#         'postalCode': '37002',
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['C. Doctrinos, 3',
#          '37002 Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d123941735',
#          'name': 'Wine Bar',
#          'pluralName': 'Wine Bars',
#          'shortName': 'Wine Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c497ecbb5eec9b6e94acfa4-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ce5a1f88ef78cfaf713879b',
#        'name': 'La Tagliatella',
#        'location': {'address': 'C. Compañía, 48-50',
#         'lat': 40.964844531288826,
#         'lng': -5.666486796731649,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.964844531288826,
#           'lng': -5.666486796731649}],
#         'distance': 210,
#         'postalCode': '37002',
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['C. Compañía, 48-50',
#          '37002 Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ce5a1f88ef78cfaf713879b-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c66b817f7a80f4712b69e7a',
#        'name': 'Casa Vallejo',
#        'location': {'address': 'San Juan de la Cruz 3',
#         'lat': 40.96406634433928,
#         'lng': -5.663336404611824,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96406634433928,
#           'lng': -5.663336404611824}],
#         'distance': 134,
#         'postalCode': '37008',
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['San Juan de la Cruz 3',
#          '37008 Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c66b817f7a80f4712b69e7a-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c2603d3c11dc9b6b71d2824',
#        'name': 'Revolutum Hostel',
#        'location': {'address': 'C. Sánchez Barbero, 7',
#         'lat': 40.963763692410254,
#         'lng': -5.664322648651452,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.963763692410254,
#           'lng': -5.664322648651452}],
#         'distance': 157,
#         'postalCode': '37001',
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['C. Sánchez Barbero, 7',
#          '37001 Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1d5941735',
#          'name': 'Hotel Bar',
#          'pluralName': 'Hotel Bars',
#          'shortName': 'Hotel Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c2603d3c11dc9b6b71d2824-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '510c2221e4b0faae2a4de2df',
#        'name': 'iPan iVino',
#        'location': {'lat': 40.96346601143018,
#         'lng': -5.664555188533585,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96346601143018,
#           'lng': -5.664555188533585}],
#         'distance': 193,
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Salamanca Castilla y León', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d123941735',
#          'name': 'Wine Bar',
#          'pluralName': 'Wine Bars',
#          'shortName': 'Wine Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-510c2221e4b0faae2a4de2df-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c35d4a73896e21e34c2ed90',
#        'name': 'La Hoja 21',
#        'location': {'address': 'Calle de San Pablo, 31',
#         'lat': 40.96170144738482,
#         'lng': -5.664190190582029,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96170144738482,
#           'lng': -5.664190190582029}],
#         'distance': 384,
#         'postalCode': '37008',
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Calle de San Pablo, 31',
#          '37008 Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c35d4a73896e21e34c2ed90-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d8cfd7c1d06b1f7285e263b',
#        'name': 'Momo',
#        'location': {'address': 'C/ San Pablo13',
#         'crossStreet': 'Pza. Colón',
#         'lat': 40.96316676888013,
#         'lng': -5.664080748962312,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96316676888013,
#           'lng': -5.664080748962312}],
#         'distance': 221,
#         'postalCode': '37001',
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['C/ San Pablo13 (Pza. Colón)',
#          '37001 Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1db931735',
#          'name': 'Tapas Restaurant',
#          'pluralName': 'Tapas Restaurants',
#          'shortName': 'Tapas',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d8cfd7c1d06b1f7285e263b-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d7220e1946b6dcb9e56367a',
#        'name': 'La Industrial',
#        'location': {'address': 'Rúa Mayor 8',
#         'lat': 40.96371303489496,
#         'lng': -5.664911270141602,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96371303489496,
#           'lng': -5.664911270141602}],
#         'distance': 177,
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Rúa Mayor 8',
#          'Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d7220e1946b6dcb9e56367a-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc73c816501c9b657fe3d29',
#        'name': 'Casa de las Conchas',
#        'location': {'address': 'C. Compañía, 2',
#         'crossStreet': 'C. Rúa Mayor',
#         'lat': 40.96266668389406,
#         'lng': -5.665893822293013,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96266668389406,
#           'lng': -5.665893822293013}],
#         'distance': 318,
#         'postalCode': '37002',
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['C. Compañía, 2 (C. Rúa Mayor)',
#          '37002 Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d12d941735',
#          'name': 'Monument / Landmark',
#          'pluralName': 'Monuments / Landmarks',
#          'shortName': 'Landmark',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_monument_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc73c816501c9b657fe3d29-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '546e2caa498e80135970c9d7',
#        'name': 'TAPAS 3.0',
#        'location': {'address': 'Sánchez Barbero 9',
#         'lat': 40.963812874496966,
#         'lng': -5.6644350154643135,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.963812874496966,
#           'lng': -5.6644350154643135}],
#         'distance': 153,
#         'postalCode': '37001',
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Sánchez Barbero 9',
#          '37001 Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1db931735',
#          'name': 'Tapas Restaurant',
#          'pluralName': 'Tapas Restaurants',
#          'shortName': 'Tapas',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '103634316'}},
#       'referralId': 'e-0-546e2caa498e80135970c9d7-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c818d1edc018cfab514c76c',
#        'name': 'Paniagua',
#        'location': {'address': 'C. Varillas',
#         'lat': 40.96411482823169,
#         'lng': -5.6624037824521825,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96411482823169,
#           'lng': -5.6624037824521825}],
#         'distance': 178,
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['C. Varillas',
#          'Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'shortName': 'Pub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c818d1edc018cfab514c76c-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fcb854de4b068d420129ba0',
#        'name': 'Plaza del Corrillo',
#        'location': {'address': 'Plaza del Corrillo',
#         'lat': 40.96424738674878,
#         'lng': -5.664865470521025,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96424738674878,
#           'lng': -5.664865470521025}],
#         'distance': 123,
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Plaza del Corrillo',
#          'Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fcb854de4b068d420129ba0-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c5201ca2543a593ffeaca84',
#        'name': 'Catedral de Salamanca',
#        'location': {'address': 'Pl. de Anaya',
#         'lat': 40.961152838856734,
#         'lng': -5.666447936305918,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.961152838856734,
#           'lng': -5.666447936305918}],
#         'distance': 490,
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Pl. de Anaya',
#          'Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d132941735',
#          'name': 'Church',
#          'pluralName': 'Churches',
#          'shortName': 'Church',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c5201ca2543a593ffeaca84-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f5dcaace4b03a6a138ad51a',
#        'name': 'Croissantería París',
#        'location': {'address': 'Rúa Mayor',
#         'lat': 40.96227651100867,
#         'lng': -5.66589025788647,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96227651100867,
#           'lng': -5.66589025788647}],
#         'distance': 357,
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Rúa Mayor',
#          'Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f5dcaace4b03a6a138ad51a-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5388dc99498eed7dcdab5292',
#        'name': 'La Malhablada',
#        'location': {'lat': 40.96330576634143,
#         'lng': -5.666079723645177,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96330576634143,
#           'lng': -5.666079723645177}],
#         'distance': 269,
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Salamanca Castilla y León', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d135941735',
#          'name': 'Indie Theater',
#          'pluralName': 'Indie Theaters',
#          'shortName': 'Indie',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5388dc99498eed7dcdab5292-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be9b74f62c0c928e7fcdfd4',
#        'name': 'Hotel Catalonia Plaza Mayor Salamanca',
#        'location': {'address': 'Espoz y Mina 23-25',
#         'lat': 40.96547328105359,
#         'lng': -5.665059287605767,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96547328105359,
#           'lng': -5.665059287605767}],
#         'distance': 94,
#         'postalCode': '37002',
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Espoz y Mina 23-25',
#          '37002 Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be9b74f62c0c928e7fcdfd4-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cb1d475562d224b59d22188',
#        'name': 'Convento de San Esteban',
#        'location': {'address': 'Pz. del Concilio de Trento, s/n',
#         'lat': 40.96066224350838,
#         'lng': -5.663419232635722,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96066224350838,
#           'lng': -5.663419232635722}],
#         'distance': 502,
#         'postalCode': '37001',
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Pz. del Concilio de Trento, s/n',
#          '37001 Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d132941735',
#          'name': 'Church',
#          'pluralName': 'Churches',
#          'shortName': 'Church',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cb1d475562d224b59d22188-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c322995213c2d7febfd345d',
#        'name': 'Plaza Anaya',
#        'location': {'address': 'Pl. Anaya',
#         'lat': 40.96139565896326,
#         'lng': -5.666165428914726,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96139565896326,
#           'lng': -5.666165428914726}],
#         'distance': 455,
#         'postalCode': '37008',
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Pl. Anaya',
#          '37008 Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c322995213c2d7febfd345d-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb35e1242959c7436d0212c',
#        'name': 'Bambú',
#        'location': {'address': 'C. Prior, 4',
#         'lat': 40.96492977461327,
#         'lng': -5.664997656474677,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96492977461327,
#           'lng': -5.664997656474677}],
#         'distance': 86,
#         'postalCode': '37002',
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['C. Prior, 4',
#          '37002 Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb35e1242959c7436d0212c-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55a6bab7498ee51f6cc3bf7b',
#        'name': 'Oro Viejo',
#        'location': {'address': 'Pl. San Benito, 5',
#         'lat': 40.96371772150311,
#         'lng': -5.666200632539453,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96371772150311,
#           'lng': -5.666200632539453}],
#         'distance': 243,
#         'postalCode': '37002',
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Pl. San Benito, 5',
#          '37002 Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55a6bab7498ee51f6cc3bf7b-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e57df7b52b1748f806e0df6',
#        'name': 'NH Palacio de Castellanos',
#        'location': {'address': 'C. San Pablo, 58-64',
#         'lat': 40.961071393408204,
#         'lng': -5.664503844274062,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.961071393408204,
#           'lng': -5.664503844274062}],
#         'distance': 456,
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['C. San Pablo, 58-64',
#          'Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e57df7b52b1748f806e0df6-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cde9c81aba88cfa55e642d7',
#        'name': 'El Alquimista',
#        'location': {'address': 'Plaza San Cristóbal, 6, BAJO',
#         'lat': 40.964421382,
#         'lng': -5.659273484,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.964421382,
#           'lng': -5.659273484}],
#         'distance': 407,
#         'postalCode': '37001',
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Plaza San Cristóbal, 6, BAJO',
#          '37001 Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cde9c81aba88cfa55e642d7-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c3772263849c928a0b7bdb1',
#        'name': 'Vinodiario',
#        'location': {'address': 'Pza. de los Basilios 1',
#         'lat': 40.961348252629875,
#         'lng': -5.66171097947038,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.961348252629875,
#           'lng': -5.66171097947038}],
#         'distance': 466,
#         'postalCode': '37001',
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Pza. de los Basilios 1',
#          '37001 Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d123941735',
#          'name': 'Wine Bar',
#          'pluralName': 'Wine Bars',
#          'shortName': 'Wine Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c3772263849c928a0b7bdb1-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbe13db8ec3d13ae4e21c28',
#        'name': "St. Patrick's Museum",
#        'location': {'address': 'Obispo Jarrín',
#         'crossStreet': 'Plaza del Mercado',
#         'lat': 40.96483478224374,
#         'lng': -5.662614899681237,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96483478224374,
#           'lng': -5.662614899681237}],
#         'distance': 123,
#         'postalCode': '37002',
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Obispo Jarrín (Plaza del Mercado)',
#          '37002 Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a06',
#          'name': 'Irish Pub',
#          'pluralName': 'Irish Pubs',
#          'shortName': 'Irish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bbe13db8ec3d13ae4e21c28-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '549355b3498eccc96c145a59',
#        'name': 'The Doctor Cocktail',
#        'location': {'address': 'Doctor Piñuela, 5',
#         'lat': 40.9656895336308,
#         'lng': -5.663346511680268,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.9656895336308,
#           'lng': -5.663346511680268}],
#         'distance': 81,
#         'postalCode': '37002',
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Doctor Piñuela, 5',
#          '37002 Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'shortName': 'Cocktail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-549355b3498eccc96c145a59-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c61bb40ec94a593bd9d27ca',
#        'name': 'Taberna de Dionisos',
#        'location': {'address': 'Iscar Peyra 16',
#         'lat': 40.9655406473463,
#         'lng': -5.6657592179410345,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.9655406473463,
#           'lng': -5.6657592179410345}],
#         'distance': 152,
#         'postalCode': '37002',
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Iscar Peyra 16',
#          '37002 Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1db931735',
#          'name': 'Tapas Restaurant',
#          'pluralName': 'Tapas Restaurants',
#          'shortName': 'Tapas',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c61bb40ec94a593bd9d27ca-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bae1275f964a520f8803be3',
#        'name': 'Casa Paca',
#        'location': {'address': 'Pza. del Peso 10',
#         'crossStreet': 'San Pablo',
#         'lat': 40.96391000981074,
#         'lng': -5.663811273301455,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96391000981074,
#           'lng': -5.663811273301455}],
#         'distance': 139,
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Pza. del Peso 10 (San Pablo)',
#          'Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bae1275f964a520f8803be3-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f1ed29fe4b026f19b57870a',
#        'name': 'Ieronimus',
#        'location': {'address': 'Pl. de Juan',
#         'lat': 40.960392,
#         'lng': -5.66677,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.960392,
#           'lng': -5.66677}],
#         'distance': 578,
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Pl. de Juan',
#          'Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d12d941735',
#          'name': 'Monument / Landmark',
#          'pluralName': 'Monuments / Landmarks',
#          'shortName': 'Landmark',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_monument_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f1ed29fe4b026f19b57870a-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f7b2ea8e4b05c0cca167307',
#        'name': 'Viandas de Salamanca',
#        'location': {'address': 'Plaza Corrillo',
#         'lat': 40.96439356675763,
#         'lng': -5.664718151092529,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96439356675763,
#           'lng': -5.664718151092529}],
#         'distance': 103,
#         'postalCode': '37002',
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Plaza Corrillo',
#          '37002 Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1f5941735',
#          'name': 'Gourmet Shop',
#          'pluralName': 'Gourmet Shops',
#          'shortName': 'Gourmet',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f7b2ea8e4b05c0cca167307-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d602c07865a224bece8a785',
#        'name': 'Plaza de Carmelitas',
#        'location': {'address': 'Plaza de Carmelitas',
#         'lat': 40.96864534423124,
#         'lng': -5.667675575007186,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96864534423124,
#           'lng': -5.667675575007186}],
#         'distance': 495,
#         'postalCode': '37007',
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Plaza de Carmelitas',
#          '37007 Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d602c07865a224bece8a785-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d0ac1c0dd5fa1cdf7555589',
#        'name': 'Centenera',
#        'location': {'lat': 40.96177589952265,
#         'lng': -5.662437337371877,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96177589952265,
#           'lng': -5.662437337371877}],
#         'distance': 399,
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Salamanca Castilla y León', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d0ac1c0dd5fa1cdf7555589-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d4c67cce4fd6ea83a45c361',
#        'name': 'Tapas 2.0',
#        'location': {'address': 'C. Felipe Espino, 10',
#         'lat': 40.96348842828155,
#         'lng': -5.6646483560601215,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96348842828155,
#           'lng': -5.6646483560601215}],
#         'distance': 193,
#         'postalCode': '37001',
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['C. Felipe Espino, 10',
#          '37001 Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d155941735',
#          'name': 'Gastropub',
#          'pluralName': 'Gastropubs',
#          'shortName': 'Gastropub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d4c67cce4fd6ea83a45c361-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e68cbb3c65be3a5651814b7',
#        'name': 'Fachada Universidad',
#        'location': {'lat': 40.96158082769168,
#         'lng': -5.6674126843411825,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96158082769168,
#           'lng': -5.6674126843411825}],
#         'distance': 489,
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Salamanca Castilla y León', 'España']},
#        'categories': [{'id': '4deefb944765f83613cdba6e',
#          'name': 'Historic Site',
#          'pluralName': 'Historic Sites',
#          'shortName': 'Historic Site',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e68cbb3c65be3a5651814b7-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a6f83692347246ed4e1c562',
#        'name': 'Goiko Grill',
#        'location': {'address': 'Calle De Correhuela',
#         'crossStreet': 'Calle Bermejeros',
#         'lat': 40.965184,
#         'lng': -5.661171,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.965184,
#           'lng': -5.661171}],
#         'distance': 239,
#         'postalCode': '37004',
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Calle De Correhuela (Calle Bermejeros)',
#          '37004 Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a6f83692347246ed4e1c562-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fdb3005e4b0f3760b44fe33',
#        'name': 'El Laurel',
#        'location': {'address': 'C. San Pablo, 49',
#         'lat': 40.95979242053987,
#         'lng': -5.664388359982038,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.95979242053987,
#           'lng': -5.664388359982038}],
#         'distance': 598,
#         'postalCode': '37008',
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['C. San Pablo, 49',
#          '37008 Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fdb3005e4b0f3760b44fe33-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd371b977b29c74f7e19082',
#        'name': "Cervecería O'hara's",
#        'location': {'address': 'C. Zamora, 14',
#         'lat': 40.9658926526226,
#         'lng': -5.663985857398969,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.9658926526226,
#           'lng': -5.663985857398969}],
#         'distance': 81,
#         'postalCode': '37002',
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['C. Zamora, 14',
#          '37002 Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '50327c8591d4c4b30a586d5d',
#          'name': 'Brewery',
#          'pluralName': 'Breweries',
#          'shortName': 'Brewery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd371b977b29c74f7e19082-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c0b4bf2ed259521ad491356',
#        'name': 'Parque de los Jesuitas',
#        'location': {'address': 'Paseo de San Antonio 14',
#         'lat': 40.96245207147332,
#         'lng': -5.656483946025997,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96245207147332,
#           'lng': -5.656483946025997}],
#         'distance': 701,
#         'postalCode': '37001',
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Paseo de San Antonio 14',
#          '37001 Salamanca Castilla y León',
# ...
#         'distance': 823,
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Paseo de la Estacion',
#          'Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c0bf5c8ffb8c9b6b10a6e61-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5149f823e4b07b89b31c793f',
#        'name': 'Brocense 22',
#        'location': {'address': 'Calle Brocense 22',
#         'lat': 40.966579756566254,
#         'lng': -5.662803562021579,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.966579756566254,
#           'lng': -5.662803562021579}],
#         'distance': 188,
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Calle Brocense 22',
#          'Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5149f823e4b07b89b31c793f-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd1efe32572ce729e5611ad',
#        'name': 'Parador de Salamanca',
#        'location': {'address': 'C/ Teso de la Feria, 2',
#         'lat': 40.95333260379773,
#         'lng': -5.672205050107029,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.95333260379773,
#           'lng': -5.672205050107029}],
#         'distance': 1485,
#         'postalCode': '37008',
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['C/ Teso de la Feria, 2',
#          '37008 Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd1efe32572ce729e5611ad-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c8d1bb25e38b1f7d75137f9',
#        'name': 'Centro de las Artes Escénicas y de la Música (CAEM)',
#        'location': {'address': 'C. Príncipe de Vergara, 73-85',
#         'lat': 40.95984087792099,
#         'lng': -5.653019199483297,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.95984087792099,
#           'lng': -5.653019199483297}],
#         'distance': 1097,
#         'postalCode': 'España',
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['C. Príncipe de Vergara, 73-85',
#          'España Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e2931735',
#          'name': 'Art Gallery',
#          'pluralName': 'Art Galleries',
#          'shortName': 'Art Gallery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c8d1bb25e38b1f7d75137f9-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bae8cc6f964a52098bf3be3',
#        'name': 'The Irish Rover',
#        'location': {'address': 'C. Rúa Antigua, 11',
#         'crossStreet': 'Francisco de Vitoria',
#         'lat': 40.96257481028326,
#         'lng': -5.666301706517322,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96257481028326,
#           'lng': -5.666301706517322}],
#         'distance': 345,
#         'postalCode': '37002',
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['C. Rúa Antigua, 11 (Francisco de Vitoria)',
#          '37002 Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d11f941735',
#          'name': 'Nightclub',
#          'pluralName': 'Nightclubs',
#          'shortName': 'Nightclub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bae8cc6f964a52098bf3be3-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d91017962f1dcb3f7928d12',
#        'name': 'Museo del Comercio',
#        'location': {'address': 'Av. Campoamor 37',
#         'lat': 40.96498847562353,
#         'lng': -5.65401042976991,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96498847562353,
#           'lng': -5.65401042976991}],
#         'distance': 841,
#         'postalCode': '37003',
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Av. Campoamor 37',
#          '37003 Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d181941735',
#          'name': 'Museum',
#          'pluralName': 'Museums',
#          'shortName': 'Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d91017962f1dcb3f7928d12-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51d29ae4498ea3694c442dd8',
#        'name': 'Beeca Restaurante Da2',
#        'location': {'address': 'Avd De Las Artesa',
#         'lat': 40.95905759483838,
#         'lng': -5.652457737869712,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.95905759483838,
#           'lng': -5.652457737869712}],
#         'distance': 1185,
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Avd De Las Artesa',
#          'Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51d29ae4498ea3694c442dd8-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dbbf18e6a23e294ba20c20a',
#        'name': 'Plaza de Los Bandos',
#        'location': {'address': 'Pl. de los Bandos',
#         'lat': 40.96703739683275,
#         'lng': -5.66444456577301,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96703739683275,
#           'lng': -5.66444456577301}],
#         'distance': 212,
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Pl. de los Bandos',
#          'Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dbbf18e6a23e294ba20c20a-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b964e66f964a5201ac534e3',
#        'name': 'Restaurante Arzobispo Fonseca',
#        'location': {'address': 'Calle de Fonseca, 4',
#         'lat': 40.9654731878587,
#         'lng': -5.670141202517329,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.9654731878587,
#           'lng': -5.670141202517329}],
#         'distance': 515,
#         'postalCode': '37002',
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Calle de Fonseca, 4',
#          '37002 Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c0941735',
#          'name': 'Mediterranean Restaurant',
#          'pluralName': 'Mediterranean Restaurants',
#          'shortName': 'Mediterranean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b964e66f964a5201ac534e3-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be123980f03a593129c18b4',
#        'name': 'Bar Puccini',
#        'location': {'address': 'calle libreros',
#         'lat': 40.96074366777229,
#         'lng': -5.668254848257379,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96074366777229,
#           'lng': -5.668254848257379}],
#         'distance': 606,
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['calle libreros',
#          'Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be123980f03a593129c18b4-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c2c95fa8abca593a4e00120',
#        'name': 'Patio Chico',
#        'location': {'address': 'Zamora',
#         'crossStreet': 'Brocense',
#         'lat': 40.96677352692592,
#         'lng': -5.6640378614462765,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96677352692592,
#           'lng': -5.6640378614462765}],
#         'distance': 179,
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Zamora (Brocense)',
#          'Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c2c95fa8abca593a4e00120-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e909a9e8b81c6df65c5e560',
#        'name': 'Gran Hotel Corona Sol',
#        'location': {'lat': 40.96891927691557,
#         'lng': -5.66997663396591,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96891927691557,
#           'lng': -5.66997663396591}],
#         'distance': 652,
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Salamanca Castilla y León', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d1f8931735',
#          'name': 'Bed & Breakfast',
#          'pluralName': 'Bed & Breakfasts',
#          'shortName': 'B & B',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/bedandbreakfast_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e909a9e8b81c6df65c5e560-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e63bc9945ddda352a21cc7c',
#        'name': 'El Retiro del Campus',
#        'location': {'address': 'Av. Champagnat, 54',
#         'crossStreet': 'Arapiles',
#         'lat': 40.96885737829807,
#         'lng': -5.674654814638685,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.96885737829807,
#           'lng': -5.674654814638685}],
#         'distance': 984,
#         'postalCode': '37007',
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Av. Champagnat, 54 (Arapiles)',
#          '37007 Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e63bc9945ddda352a21cc7c-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c252923905a0f47ff066160',
#        'name': 'El Patio de la Abuela',
#        'location': {'address': 'C. Van Dyck',
#         'lat': 40.97335548956163,
#         'lng': -5.661844963711037,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.97335548956163,
#           'lng': -5.661844963711037}],
#         'distance': 930,
#         'cc': 'ES',
#         'city': 'Salamanca',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['C. Van Dyck',
#          'Salamanca Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1db931735',
#          'name': 'Tapas Restaurant',
#          'pluralName': 'Tapas Restaurants',
#          'shortName': 'Tapas',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c252923905a0f47ff066160-99'}]}]}}

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues_def=nearby_venues
nearby_venues_def.head(10)
# Out:
#   postalCode              name          categories        lat       lng
# 0      37002       Plaza Mayor               Plaza  40.965009 -5.664117
# 1      37002      Cuzco Bodega    Tapas Restaurant  40.964170 -5.665567
# 2        NaN   Capitán Haddock        Cocktail Bar  40.966406 -5.664584
# 3        NaN    The Holy Cross                 Pub  40.964728 -5.661910
# 4      37002         Doctrinos            Wine Bar  40.964728 -5.665949
# 5      37002    La Tagliatella  Italian Restaurant  40.964845 -5.666487
# 6      37008      Casa Vallejo  Spanish Restaurant  40.964066 -5.663336
# 7      37001  Revolutum Hostel           Hotel Bar  40.963764 -5.664323
# 8        NaN        iPan iVino            Wine Bar  40.963466 -5.664555
# 9      37008        La Hoja 21  Spanish Restaurant  40.961701 -5.664190

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues_def.shape[0]))
# Out:
# 100 venues were returned by Foursquare.

# %%
nearby_venues_def.groupby('postalCode').count()
# Out:
#             name  categories  lat  lng
# postalCode
# 37001         10          10   10   10
# 37002         22          22   22   22
# 37003          2           2    2    2
# 37004          2           2    2    2
# 37005          3           3    3    3
# 37007          2           2    2    2
# 37008         16          16   16   16
# España         1           1    1    1

# %%
# one hot encoding
sal_onehot = pd.get_dummies(nearby_venues_def['categories'], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
sal_onehot['postalCode'] = nearby_venues['postalCode'] 

# move neighborhood column to the first column
fixed_columns = [sal_onehot.columns[-1]] + list(sal_onehot.columns[:-1])

sal_onehot = sal_onehot[fixed_columns]

#Next, let's group rows by neighborhood and by taking the mean of the frequency of occurrence of each category
sal_grouped = sal_onehot.groupby('postalCode').mean().reset_index()


sal_onehot.shape
# Out:
# (100, 42)

# %%
num_top_venues = 5

for hood in sal_grouped['postalCode']:
    print("----"+hood+"----")
    temp = sal_grouped[sal_grouped['postalCode'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----37001----
#               venue  freq
# 0  Tapas Restaurant   0.3
# 1          Wine Bar   0.1
# 2        Restaurant   0.1
# 3         Gastropub   0.1
# 4              Park   0.1
#
#
# ----37002----
#                       venue  freq
# 0          Tapas Restaurant  0.09
# 1                      Café  0.09
# 2  Mediterranean Restaurant  0.09
# 3                     Hotel  0.05
# 4              Gourmet Shop  0.05
#
#
# ----37003----
#                 venue  freq
# 0                Park   0.5
# 1              Museum   0.5
# 2           Hotel Bar   0.0
# 3           Irish Pub   0.0
# 4  Italian Restaurant   0.0
#
#
# ----37004----
#                 venue  freq
# 0               Plaza   0.5
# 1        Burger Joint   0.5
# 2                Park   0.0
# 3           Irish Pub   0.0
# 4  Italian Restaurant   0.0
#
#
# ----37005----
#                  venue  freq
# 0                  Bar  0.25
# 1     Tapas Restaurant  0.25
# 2  Japanese Restaurant  0.25
# 3                Diner  0.25
# 4          Art Gallery  0.00
#
#
# ----37007----
#                 venue  freq
# 0               Hotel  0.33
# 1         Coffee Shop  0.33
# 2               Plaza  0.33
# 3           Irish Pub  0.00
# 4  Italian Restaurant  0.00
#
#
# ----37008----
#                  venue  freq
# 0                Hotel  0.29
# 1           Art Museum  0.14
# 2   Spanish Restaurant  0.14
# 3                 Café  0.07
# 4  Monument / Landmark  0.07
#
#
# ----España----
#                  venue  freq
# 0          Art Gallery   1.0
# 1            Hotel Bar   0.0
# 2            Irish Pub   0.0
# 3   Italian Restaurant   0.0
# 4  Japanese Restaurant   0.0

# %%
sal_grouped
# Out:
#   postalCode  Art Gallery  Art Museum  Bakery       Bar  Bed & Breakfast  \
# 0      37001          0.0       0.000     0.0  0.000000              0.0
# 1      37002          0.0       0.000     0.0  0.045455              0.0
# 2      37003          0.0       0.000     0.0  0.000000              0.0
# 3      37004          0.0       0.000     0.0  0.000000              0.0
# 4      37005          0.0       0.000     0.0  0.000000              0.0
# 5      37007          0.0       0.000     0.0  0.000000              0.0
# 6      37008          0.0       0.125     0.0  0.062500              0.0
# 7     España          1.0       0.000     0.0  0.000000              0.0
#
#     Brewery  Burger Joint      Café  Church  Clothing Store  Cocktail Bar  \
# 0  0.000000           0.0  0.000000     0.1             0.1      0.000000
# 1  0.045455           0.0  0.045455     0.0             0.0      0.045455
# 2  0.000000           0.0  0.000000     0.0             0.0      0.000000
# 3  0.000000           0.5  0.000000     0.0             0.0      0.000000
# 4  0.000000           0.0  0.000000     0.0             0.0      0.000000
# 5  0.000000           0.0  0.000000     0.0             0.0      0.000000
# 6  0.000000           0.0  0.062500     0.0             0.0      0.000000
# 7  0.000000           0.0  0.000000     0.0             0.0      0.000000
#
#    Coffee Shop  College Quad  Concert Hall  Dessert Shop     Diner  Garden  \
# 0          0.0        0.0000      0.000000           0.0  0.000000     0.0
# 1          0.0        0.0000      0.045455           0.0  0.000000     0.0
# 2          0.0        0.0000      0.000000           0.0  0.000000     0.0
# 3          0.0        0.0000      0.000000           0.0  0.000000     0.0
# 4          0.0        0.0000      0.000000           0.0  0.333333     0.0
# 5          0.5        0.0000      0.000000           0.0  0.000000     0.0
# 6          0.0        0.0625      0.000000           0.0  0.000000     0.0
# 7          0.0        0.0000      0.000000           0.0  0.000000     0.0
#
#    Gastropub  Gourmet Shop  Historic Site     Hotel  Hotel Bar  Indie Theater  \
# 0        0.1      0.000000            0.0  0.000000        0.1            0.0
# 1        0.0      0.045455            0.0  0.045455        0.0            0.0
# 2        0.0      0.000000            0.0  0.000000        0.0            0.0
# 3        0.0      0.000000            0.0  0.000000        0.0            0.0
# 4        0.0      0.000000            0.0  0.000000        0.0            0.0
# 5        0.0      0.000000            0.0  0.000000        0.0            0.0
# 6        0.0      0.000000            0.0  0.250000        0.0            0.0
# 7        0.0      0.000000            0.0  0.000000        0.0            0.0
#
#    Irish Pub  Italian Restaurant  Japanese Restaurant  \
# 0   0.000000            0.000000             0.000000
# 1   0.045455            0.045455             0.000000
# 2   0.000000            0.000000             0.000000
# 3   0.000000            0.000000             0.000000
# 4   0.000000            0.000000             0.333333
# 5   0.000000            0.000000             0.000000
# 6   0.000000            0.000000             0.000000
# 7   0.000000            0.000000             0.000000
#
#    Mediterranean Restaurant  Middle Eastern Restaurant  Monument / Landmark  \
# 0                  0.000000                        0.0             0.000000
# 1                  0.090909                        0.0             0.045455
# 2                  0.000000                        0.0             0.000000
# 3                  0.000000                        0.0             0.000000
# 4                  0.000000                        0.0             0.000000
# 5                  0.000000                        0.0             0.000000
# 6                  0.000000                        0.0             0.062500
# 7                  0.000000                        0.0             0.000000
#
#    Museum  Nightclub      Park     Plaza       Pub  Restaurant  River  \
# 0     0.0   0.000000  0.100000  0.000000  0.000000    0.100000    0.0
# 1     0.0   0.045455  0.045455  0.045455  0.090909    0.045455    0.0
# 2     0.5   0.000000  0.500000  0.000000  0.000000    0.000000    0.0
# 3     0.0   0.000000  0.000000  0.500000  0.000000    0.000000    0.0
# 4     0.0   0.000000  0.000000  0.000000  0.000000    0.000000    0.0
# 5     0.0   0.000000  0.000000  0.500000  0.000000    0.000000    0.0
# 6     0.0   0.000000  0.000000  0.062500  0.000000    0.062500    0.0
# 7     0.0   0.000000  0.000000  0.000000  0.000000    0.000000    0.0
#
#    Snack Place  Spanish Restaurant  Tapas Restaurant  \
# 0       0.0000            0.000000          0.300000
# 1       0.0000            0.045455          0.090909
# 2       0.0000            0.000000          0.000000
# 3       0.0000            0.000000          0.000000
# 4       0.0000            0.000000          0.333333
# 5       0.0000            0.000000          0.000000
# 6       0.0625            0.125000          0.000000
# 7       0.0000            0.000000          0.000000
#
#    Vegetarian / Vegan Restaurant  Wine Bar
# 0                         0.0000  0.100000
# 1                         0.0000  0.045455
# 2                         0.0000  0.000000
# 3                         0.0000  0.000000
# 4                         0.0000  0.000000
# 5                         0.0000  0.000000
# 6                         0.0625  0.000000
# 7                         0.0000  0.000000

# %%
 #set number of clusters
kclusters = 3

sal_grouped_clustering = sal_grouped.drop('postalCode', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(sal_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_
# Out:
# array([0, 0, 0, 2, 0, 2, 0, 1], dtype=int32)

# %%
# add clustering labels
#sal_merged = df_def.loc[df_def['Neighbourhood'].isin(neighborhoods_venues_sorted['Neighborhood'])]
sal_merged = nearby_venues_def.groupby('postalCode').count()
sal_merged['Cluster Labels'] = kmeans.labels_


sal_merged # check the last columns!
# Out:
#             name  categories  lat  lng  Cluster Labels
# postalCode
# 37001         10          10   10   10               0
# 37002         22          22   22   22               0
# 37003          2           2    2    2               0
# 37004          2           2    2    2               2
# 37005          3           3    3    3               0
# 37007          2           2    2    2               2
# 37008         16          16   16   16               0
# España         1           1    1    1               1

# %%
nearby_venues_def.groupby('categories').count().index
# Out:
# Index(['Art Gallery', 'Art Museum', 'Bakery', 'Bar', 'Bed & Breakfast',
#        'Brewery', 'Burger Joint', 'Café', 'Church', 'Clothing Store',
#        'Cocktail Bar', 'Coffee Shop', 'College Quad', 'Concert Hall',
#        'Dessert Shop', 'Diner', 'Garden', 'Gastropub', 'Gourmet Shop',
#        'Historic Site', 'Hotel', 'Hotel Bar', 'Indie Theater', 'Irish Pub',
#        'Italian Restaurant', 'Japanese Restaurant', 'Mediterranean Restaurant',
#        'Middle Eastern Restaurant', 'Monument / Landmark', 'Museum',
#        'Nightclub', 'Park', 'Plaza', 'Pub', 'Restaurant', 'River',
#        'Snack Place', 'Spanish Restaurant', 'Tapas Restaurant',
#        'Vegetarian / Vegan Restaurant', 'Wine Bar'],
#       dtype='object', name='categories')

# %%
# create map
map_clusters = folium.Map(location=[latitude_sal, longitude_sal], zoom_start=10)

# set color scheme for the clusters
x = np.arange(8)
ys = [i + x + (i*x)**2 for i in range(8)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]
print(rainbow)
postal = list(nearby_venues_def.groupby('postalCode').count().index)
print(postal)

# add markers to the map
markers_colors = []
for lat, lon, post, name in zip(nearby_venues_def['lat'], nearby_venues_def['lng'] , nearby_venues_def['postalCode'], nearby_venues_def['name']):
    label = folium.Popup(str(name) + ' category ' + str(post), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=3,
        popup=label,
        color='#386df9',
        fill=True,
        fill_color='#386df9',
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# ['#8000ff', '#386df9', '#12c8e6', '#5af8c8', '#a4f89f', '#ecc86f', '#ff6d38', '#ff0000']
# ['37001', '37002', '37003', '37004', '37005', '37007', '37008', 'España']
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
